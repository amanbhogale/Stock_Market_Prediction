# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data
import yfinance as yf
import mpl_finance

from mpl_finance import candlestick_ohlc
import datetime
import matplotlib.dates as mpl_dates
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import pandas_datareader as data
#       5 import yfinance as yf
# ----> 6 import mpl_finance
#       8 from mpl_finance import candlestick_ohlc
#       9 import datetime
#
# ModuleNotFoundError: No module named 'mpl_finance'

# %%
start = "2010-01-01"
end = "2015-12-31"

# df = yf.download("AAPL", start=start, end=end)
df = yf.download("AAPL",start=start,end=end)
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.478998  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.490199  601904800
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.386965  552160000
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.375156  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.417542  447610800

# %%
df.tail()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2015-12-23  26.817499  27.212500  26.799999  27.152500  24.719450  130629600
# 2015-12-24  27.250000  27.250000  26.987499  27.007500  24.587442   54281600
# 2015-12-28  26.897499  26.922501  26.545000  26.705000  24.312044  106816800
# 2015-12-29  26.740000  27.357500  26.715000  27.184999  24.749037  123724800
# 2015-12-30  27.145000  27.174999  26.795000  26.830000  24.425848  100855200

# %%
print(df.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df = df.reset_index()
df.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.478998  493729600
# 1 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.490199  601904800
# 2 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.386965  552160000
# 3 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.375156  477131200
# 4 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.417542  447610800

# %%
print(df.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df = df.drop(['Date','Adj Close'],axis=1)
df.head()
# Out:
#        Open      High       Low     Close     Volume
# 0  7.622500  7.660714  7.585000  7.643214  493729600
# 1  7.664286  7.699643  7.616071  7.656429  601904800
# 2  7.656429  7.686786  7.526786  7.534643  552160000
# 3  7.562500  7.571429  7.466071  7.520714  477131200
# 4  7.510714  7.571429  7.466429  7.570714  447610800

# %%
plt.plot(df.Close)

# %%
df
# Out:
#            Open       High        Low      Close     Volume
# 0      7.622500   7.660714   7.585000   7.643214  493729600
# 1      7.664286   7.699643   7.616071   7.656429  601904800
# 2      7.656429   7.686786   7.526786   7.534643  552160000
# 3      7.562500   7.571429   7.466071   7.520714  477131200
# 4      7.510714   7.571429   7.466429   7.570714  447610800
# ...         ...        ...        ...        ...        ...
# 1504  26.817499  27.212500  26.799999  27.152500  130629600
# 1505  27.250000  27.250000  26.987499  27.007500   54281600
# 1506  26.897499  26.922501  26.545000  26.705000  106816800
# 1507  26.740000  27.357500  26.715000  27.184999  123724800
# 1508  27.145000  27.174999  26.795000  26.830000  100855200
#
# [1509 rows x 5 columns]

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 1504    28.526475
# 1505    28.509950
# 1506    28.488500
# 1507    28.472525
# 1508    28.452025
# Name: Close, Length: 1509, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'r')

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 1504    30.129975
# 1505    30.109450
# 1506    30.088487
# 1507    30.068225
# 1508    30.043575
# Name: Close, Length: 1509, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'r')
plt.plot(ma200,'g')

# %%
df.shape
# Out:
# (1509, 5)

# %%
#Splitting data into training and testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (1056, 1)
# (453, 1)

# %%
data_training.head()
# Out:
#       Close
# 0  7.643214
# 1  7.656429
# 2  7.534643
# 3  7.520714
# 4  7.570714

# %%
data_testing.head()
# Out:
#           Close
# 1056  18.812143
# 1057  18.978571
# 1058  18.973572
# 1059  18.882143
# 1060  19.031071

# %%
# Scaling the data.(b/w 0 and 1)

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.04305457],
#        [0.04378   ],
#        [0.03709439],
#        ...,
#        [0.67554155],
#        [0.66385646],
#        [0.65217138]])

# %%
data_training_array.shape
# Out:
# (1056, 1)

# %%
x_train = []
y_train = []

for i in range(100,data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i,0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (956, 100, 1)

# %%
# ML Model

from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential
# Out:
# 2023-12-11 09:36:07.460306: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-11 09:36:07.460343: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-11 09:36:07.461208: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-11 09:36:07.466867: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-11 09:36:08.401550: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model = Sequential()
model.add(LSTM(units=50, activation = 'relu', return_sequences = True,
              input_shape = (x_train.shape[1], 1))) #last '1' shows number of column
model.add(Dropout(0.2))


model.add(LSTM(units=60, activation = 'relu', return_sequences = True,))
model.add(Dropout(0.3))


model.add(LSTM(units=80, activation = 'relu', return_sequences = True,))
model.add(Dropout(0.4))


model.add(LSTM(units=120, activation = 'relu'))
model.add(Dropout(0.5))


model.add(Dense(units = 1))
# Out:
# 2023-12-11 09:36:09.389033: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-11 09:36:09.424309: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 60)           26640
#
#  dropout_1 (Dropout)         (None, 100, 60)           0
#
#  lstm_2 (LSTM)               (None, 100, 80)           45120
#
#  dropout_2 (Dropout)         (None, 100, 80)           0
#
#  lstm_3 (LSTM)               (None, 120)               96480
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 1)                 121
#
# =================================================================
# Total params: 178761 (698.29 KB)
# Trainable params: 178761 (698.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 9s 114ms/step - loss: 0.0934
# Epoch 2/50
# 30/30 [==============================] - 4s 115ms/step - loss: 0.0242
# Epoch 3/50
# 30/30 [==============================] - 4s 116ms/step - loss: 0.0141
# Epoch 4/50
# 30/30 [==============================] - 3s 105ms/step - loss: 0.0147
# Epoch 5/50
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0103
# Epoch 6/50
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0098
# Epoch 7/50
# 30/30 [==============================] - 3s 105ms/step - loss: 0.0099
# Epoch 8/50
# 30/30 [==============================] - 3s 104ms/step - loss: 0.0095
# Epoch 9/50
# 30/30 [==============================] - 3s 108ms/step - loss: 0.0089
# Epoch 10/50
# 30/30 [==============================] - 3s 106ms/step - loss: 0.0092
# Epoch 11/50
# 30/30 [==============================] - 3s 106ms/step - loss: 0.0088
# Epoch 12/50
# 30/30 [==============================] - 3s 104ms/step - loss: 0.0082
# Epoch 13/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0072
# Epoch 14/50
# 30/30 [==============================] - 3s 110ms/step - loss: 0.0086
# Epoch 15/50
# 30/30 [==============================] - 3s 102ms/step - loss: 0.0069
# Epoch 16/50
# 30/30 [==============================] - 3s 103ms/step - loss: 0.0076
# Epoch 17/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0078
# Epoch 18/50
# 30/30 [==============================] - 3s 101ms/step - loss: 0.0070
# Epoch 19/50
# 30/30 [==============================] - 3s 105ms/step - loss: 0.0071
# Epoch 20/50
# 30/30 [==============================] - 3s 104ms/step - loss: 0.0075
# Epoch 21/50
# 30/30 [==============================] - 3s 105ms/step - loss: 0.0063
# Epoch 22/50
# 30/30 [==============================] - 3s 104ms/step - loss: 0.0060
# Epoch 23/50
# 30/30 [==============================] - 3s 105ms/step - loss: 0.0061
# Epoch 24/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0063
# Epoch 25/50
# 30/30 [==============================] - 3s 116ms/step - loss: 0.0074
# Epoch 26/50
# 30/30 [==============================] - 3s 116ms/step - loss: 0.0066
# Epoch 27/50
# 30/30 [==============================] - 4s 120ms/step - loss: 0.0069
# Epoch 28/50
# 30/30 [==============================] - 4s 118ms/step - loss: 0.0059
# Epoch 29/50
# 30/30 [==============================] - 3s 112ms/step - loss: 0.0058
# Epoch 30/50
# 30/30 [==============================] - 3s 114ms/step - loss: 0.0060
# Epoch 31/50
# 30/30 [==============================] - 3s 106ms/step - loss: 0.0064
# Epoch 32/50
# 30/30 [==============================] - 3s 104ms/step - loss: 0.0054
# Epoch 33/50
# 30/30 [==============================] - 3s 105ms/step - loss: 0.0055
# Epoch 34/50
# 30/30 [==============================] - 3s 105ms/step - loss: 0.0054
# Epoch 35/50
# 30/30 [==============================] - 4s 117ms/step - loss: 0.0048
# Epoch 36/50
# 30/30 [==============================] - 4s 121ms/step - loss: 0.0052
# Epoch 37/50
# 30/30 [==============================] - 3s 109ms/step - loss: 0.0048
# Epoch 38/50
# 30/30 [==============================] - 3s 109ms/step - loss: 0.0051
# Epoch 39/50
# 30/30 [==============================] - 3s 108ms/step - loss: 0.0054
# Epoch 40/50
# 30/30 [==============================] - 3s 110ms/step - loss: 0.0061
# Epoch 41/50
# 30/30 [==============================] - 3s 107ms/step - loss: 0.0047
# Epoch 42/50
# 30/30 [==============================] - 3s 112ms/step - loss: 0.0045
# Epoch 43/50
# 30/30 [==============================] - 3s 106ms/step - loss: 0.0044
# Epoch 44/50
# 30/30 [==============================] - 3s 109ms/step - loss: 0.0046
# Epoch 45/50
# 30/30 [==============================] - 4s 118ms/step - loss: 0.0045
# Epoch 46/50
# 30/30 [==============================] - 3s 106ms/step - loss: 0.0043
# Epoch 47/50
# 30/30 [==============================] - 3s 104ms/step - loss: 0.0044
# Epoch 48/50
# 30/30 [==============================] - 3s 105ms/step - loss: 0.0044
# Epoch 49/50
# 30/30 [==============================] - 3s 104ms/step - loss: 0.0041
# Epoch 50/50
# 30/30 [==============================] - 4s 119ms/step - loss: 0.0050

# %%
# model.save('Keras_model.h5')

# %%
data_testing.head()
# Out:
#           Close
# 1056  18.812143
# 1057  18.978571
# 1058  18.973572
# 1059  18.882143
# 1060  19.031071

# %%
data_training.tail(100)
# Out:
#           Close
# 956   18.620001
# 957   18.566786
# 958   18.748571
# 959   18.996786
# 960   18.784286
# ...         ...
# 1051  18.961430
# 1052  19.146070
# 1053  19.164642
# 1054  18.951786
# 1055  18.738930
#
# [100 rows x 1 columns]

# %%
past_100_days = data_training.tail(100)

# %%
# final_df = past_100_days.append(data_testing,ignore_index = True)
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
#        Close
# 0  18.620001
# 1  18.566786
# 2  18.748571
# 3  18.996786
# 4  18.784286

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.05004415],
#        [0.04658879],
#        [0.0583925 ],
#        [0.07450959],
#        [0.06071156],
#        [0.069802  ],
#        [0.0391911 ],
#        [0.05825342],
#        [0.0531515 ],
#        [0.04695984],
#        [0.06254352],
#        [0.05952881],
#        [0.04902377],
#        [0.02947448],
#        [0.04818891],
#        [0.04468723],
#        [0.04691352],
#        [0.04835127],
#        [0.06581335],
#        [0.0584621 ],
#        [0.04371316],
#        [0.04584669],
#        [0.03529521],
#        [0.0495339 ],
#        [0.04642643],
#        [0.05556332],
#        [0.07796483],
#        [0.10709154],
#        [0.13053672],
#        [0.11931274],
#        [0.15430638],
#        [0.15124535],
#        [0.15797043],
#        [0.13969665],
#        [0.15456151],
#        [0.15252074],
#        [0.14280412],
#        [0.14090256],
#        [0.12673347],
#        [0.13385275],
#        [0.12803214],
#        [0.11824592],
#        [0.10361302],
#        [0.11418766],
#        [0.16304906],
#        [0.15743714],
#        [0.14869446],
#        [0.13985901],
#        [0.12694215],
#        [0.1420157 ],
#        [0.12371876],
#        [0.09554296],
#        [0.10238395],
#        [0.09336311],
#        [0.10129409],
#        [0.08520016],
#        [0.07689813],
#        [0.0833682 ],
#        [0.10808876],
#        [0.13352815],
#        [0.1263161 ],
#        [0.09482402],
#        [0.11430371],
#        [0.11996208],
#        [0.13079172],
#        [0.10734667],
#        [0.11761974],
#        [0.0155838 ],
#        [0.00224945],
#        [0.        ],
#        [0.00190156],
#        [0.00405825],
#        [0.02089416],
#        [0.02970644],
#        [0.02952092],
#        [0.04614814],
#        [0.06773808],
#        [0.08390161],
#        [0.08380872],
#        [0.10354354],
#        [0.10252303],
#        [0.10716114],
#        [0.08717132],
#        [0.07274711],
#        [0.059065  ],
#        [0.06439864],
#        [0.05166743],
#        [0.0407449 ],
#        [0.06467705],
#        [0.06136089],
#        [0.06488573],
#        [0.07295579],
#        [0.07555314],
#        [0.07181949],
#        [0.07110067],
#        [0.07221382],
#        [0.08420293],
#        [0.08540884],
#        [0.07158765],
#        [0.05776645],
#        [0.06252036],
#        [0.07332684],
#        [0.07300224],
#        [0.06706558],
#        [0.07673576],
#        [0.09139194],
#        [0.10484209],
#        [0.09276009],
#        [0.08738001],
#        [0.08598857],
#        [0.08571041],
#        [0.09709663],
#        [0.09918372],
#        [0.09046432],
#        [0.07430078],
#        [0.05493714],
#        [0.05486766],
#        [0.07082239],
#        [0.05496042],
#        [0.0459859 ],
#        [0.05078625],
#        [0.04215949],
#        [0.04459447],
#        [0.05834606],
#        [0.07279355],
#        [0.07402262],
#        [0.05790553],
#        [0.15766898],
#        [0.16733929],
#        [0.21870514],
#        [0.21462361],
#        [0.20942905],
#        [0.21265257],
#        [0.21520334],
#        [0.23463659],
#        [0.21944724],
#        [0.21462361],
#        [0.20455922],
#        [0.19887769],
#        [0.2157832 ],
#        [0.21793976],
#        [0.21819489],
#        [0.20648394],
#        [0.22663613],
#        [0.24305466],
#        [0.24333295],
#        [0.24704331],
#        [0.24926948],
#        [0.26517789],
#        [0.29184646],
#        [0.28808966],
#        [0.31445666],
#        [0.3089375 ],
#        [0.29884982],
#        [0.31946569],
#        [0.33634804],
#        [0.3422151 ],
#        [0.33808724],
#        [0.36204255],
#        [0.37097076],
#        [0.36463989],
#        [0.33915407],
#        [0.32275869],
#        [0.33769303],
#        [0.33574515],
#        [0.33736843],
#        [0.33217387],
#        [0.31675256],
#        [0.31545388],
#        [0.30652568],
#        [0.30782435],
#        [0.31659019],
#        [0.33412187],
#        [0.34954319],
#        [0.3591206 ],
#        [0.35847139],
#        [0.36739948],
#        [0.39889156],
#        [0.38882705],
#        [0.38947638],
#        [0.38379485],
#        [0.3867168 ],
#        [0.40668334],
#        [0.38834008],
#        [0.37957424],
#        [0.3521404 ],
#        [0.37389271],
#        [0.36593856],
#        [0.37860029],
#        [0.41869586],
#        [0.41609851],
#        [0.42648763],
#        [0.44840217],
#        [0.43801306],
#        [0.43427953],
#        [0.3928853 ],
#        [0.40148878],
#        [0.39272294],
#        [0.38509352],
#        [0.38249618],
#        [0.37470441],
#        [0.3789249 ],
#        [0.39921617],
#        [0.39889156],
#        [0.41950743],
#        [0.42372805],
#        [0.43151995],
#        [0.77712068],
#        [0.79757431],
#        [0.78085433],
#        [0.80812579],
#        [0.83068967],
#        [0.82143686],
#        [0.80390518],
#        [0.80617779],
#        [0.79822365],
#        [0.73653815],
#        [0.72582443],
#        [0.71949356],
#        [0.6646259 ],
#        [0.69449471],
#        [0.68654056],
#        [0.74497939],
#        [0.76916654],
#        [0.77760778],
#        [0.75244656],
#        [0.77078982],
#        [0.75699178],
#        [0.7534205 ],
#        [0.76137476],
#        [0.74579096],
#        [0.72858401],
#        [0.71105232],
#        [0.77322479],
#        [0.76105003],
#        [0.76023846],
#        [0.71787028],
#        [0.72679837],
#        [0.67826169],
#        [0.66689863],
#        [0.63459485],
#        [0.64839289],
#        [0.61008309],
#        [0.56219563],
#        [0.58329859],
#        [0.58167532],
#        [0.60407683],
#        [0.59466165],
#        [0.57501972],
#        [0.60618708],
#        [0.58313623]])

# %%
input_data.shape
# Out:
# (553, 1)

# %%
x_test = []
y_test = []

for i in range(100,input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i,0])

# %%
x_test , y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (453, 100, 1)
# (453,)

# %%
#Making Predictions

y_predicted = model.predict(x_test)
# Out:
# 15/15 [==============================] - 1s 31ms/step

# %%
y_predicted.shape
# Out:
# (453, 1)

# %%
y_test
# Out:
# array([0.06252036, 0.07332684, 0.07300224, 0.06706558, 0.07673576,
#        0.09139194, 0.10484209, 0.09276009, 0.08738001, 0.08598857,
#        0.08571041, 0.09709663, 0.09918372, 0.09046432, 0.07430078,
#        0.05493714, 0.05486766, 0.07082239, 0.05496042, 0.0459859 ,
#        0.05078625, 0.04215949, 0.04459447, 0.05834606, 0.07279355,
#        0.07402262, 0.05790553, 0.15766898, 0.16733929, 0.21870514,
#        0.21462361, 0.20942905, 0.21265257, 0.21520334, 0.23463659,
#        0.21944724, 0.21462361, 0.20455922, 0.19887769, 0.2157832 ,
#        0.21793976, 0.21819489, 0.20648394, 0.22663613, 0.24305466,
#        0.24333295, 0.24704331, 0.24926948, 0.26517789, 0.29184646,
#        0.28808966, 0.31445666, 0.3089375 , 0.29884982, 0.31946569,
#        0.33634804, 0.3422151 , 0.33808724, 0.36204255, 0.37097076,
#        0.36463989, 0.33915407, 0.32275869, 0.33769303, 0.33574515,
#        0.33736843, 0.33217387, 0.31675256, 0.31545388, 0.30652568,
#        0.30782435, 0.31659019, 0.33412187, 0.34954319, 0.3591206 ,
#        0.35847139, 0.36739948, 0.39889156, 0.38882705, 0.38947638,
#        0.38379485, 0.3867168 , 0.40668334, 0.38834008, 0.37957424,
#        0.3521404 , 0.37389271, 0.36593856, 0.37860029, 0.41869586,
#        0.41609851, 0.42648763, 0.44840217, 0.43801306, 0.43427953,
#        0.3928853 , 0.40148878, 0.39272294, 0.38509352, 0.38249618,
#        0.37470441, 0.3789249 , 0.39921617, 0.39889156, 0.41950743,
#        0.42372805, 0.43151995, 0.45067491, 0.47291406, 0.47356339,
#        0.91234171, 0.90747188, 0.91688693, 0.89610869, 0.91250407,
#        0.90308889, 0.92062058, 0.91071843, 0.89854367, 0.86250636,
#        0.8771161 , 0.89610869, 0.89351148, 0.88636891, 0.88133672,
#        0.83068967, 0.79010714, 0.8422151 , 0.88084975, 0.88003805,
#        0.89967998, 0.92711368, 0.94513234, 0.98490342, 0.96347572,
#        0.87370718, 0.87273324, 0.86201939, 0.83393623, 0.84383837,
#        0.83750751, 0.82744312, 0.8100738 , 0.76364737, 0.70196188,
#        0.714299  , 0.70991602, 0.71624688, 0.78442561, 0.68329389,
#        0.71170166, 0.71024075, 0.72338945, 0.74286914, 0.73215529,
#        0.70796814, 0.66965822, 0.55781277, 0.51495763, 0.52502201,
#        0.62160851, 0.67404108, 0.68004733, 0.67144386, 0.58962946,
#        0.6646259 , 0.63264697, 0.61479055, 0.66413893, 0.62907568,
#        0.66835955, 0.69498168, 0.71283797, 0.72858401, 0.73069438,
#        0.69027409, 0.68264455, 0.71121469, 0.68183298, 0.69676732,
#        0.70780577, 0.70309818, 0.6662493 , 0.61138164, 0.63151066,
#        0.61982287, 0.63280921, 0.63930244, 0.64790592, 0.63930244,
#        0.6185242 , 0.66105474, 0.6526135 , 0.65569782, 0.63004963,
#        0.65683412, 0.64352306, 0.65472387, 0.68783911, 0.68767687,
#        0.71592228, 0.77403649, 0.712351  , 0.70050097, 0.77712068,
#        0.79757431, 0.78085433, 0.80812579, 0.83068967, 0.82143686,
#        0.80390518, 0.80617779, 0.79822365, 0.73653815, 0.72582443,
#        0.71949356, 0.6646259 , 0.69449471, 0.68654056, 0.74497939,
#        0.76916654, 0.77760778, 0.75244656, 0.77078982, 0.75699178,
#        0.7534205 , 0.76137476, 0.74579096, 0.72858401, 0.71105232,
#        0.77322479, 0.76105003, 0.76023846, 0.71787028, 0.72679837,
#        0.67826169, 0.66689863, 0.63459485, 0.64839289, 0.61008309,
#        0.56219563, 0.58329859, 0.58167532, 0.60407683, 0.59466165,
#        0.57501972, 0.60618708, 0.58313623])

# %%
y_predicted
# Out:
# array([[0.1393198 ],
#        [0.13863641],
#        [0.13799948],
#        [0.13732363],
#        [0.13661808],
#        [0.13594028],
#        [0.13529347],
#        [0.13477698],
#        [0.13445246],
#        [0.13434373],
#        [0.134474  ],
#        [0.1348415 ],
#        [0.1354358 ],
#        [0.13625738],
#        [0.13730752],
#        [0.13847797],
#        [0.13957438],
#        [0.14042538],
#        [0.14101866],
#        [0.14136557],
#        [0.14144254],
#        [0.14124775],
#        [0.14080186],
#        [0.14011516],
#        [0.13923585],
#        [0.13823152],
#        [0.13716902],
#        [0.13611081],
#        [0.13517916],
#        [0.1345561 ],
#        [0.13454339],
#        [0.13543469],
#        [0.13741986],
#        [0.14053655],
#        [0.14464249],
#        [0.14947563],
#        [0.15468831],
#        [0.15994823],
#        [0.16514975],
#        [0.17034593],
#        [0.17537926],
#        [0.18029061],
#        [0.18524754],
#        [0.19020097],
#        [0.19506866],
#        [0.19976306],
#        [0.20461379],
#        [0.20968935],
#        [0.21487117],
#        [0.22014795],
#        [0.22550565],
#        [0.23103523],
#        [0.23664786],
#        [0.24217233],
#        [0.2474805 ],
#        [0.2526293 ],
#        [0.25770107],
#        [0.26282635],
#        [0.26802793],
#        [0.2734595 ],
#        [0.27923113],
#        [0.28533107],
#        [0.29151314],
#        [0.29751158],
#        [0.3030712 ],
#        [0.30799788],
#        [0.3121642 ],
#        [0.31552067],
#        [0.3179943 ],
#        [0.31956515],
#        [0.32024115],
#        [0.3201077 ],
#        [0.31931108],
#        [0.31806102],
#        [0.31662357],
#        [0.31527886],
#        [0.314274  ],
#        [0.31385598],
#        [0.3143452 ],
#        [0.31589243],
#        [0.31851867],
#        [0.32207635],
#        [0.32626724],
#        [0.33090925],
#        [0.33578867],
#        [0.34065628],
#        [0.3451676 ],
#        [0.34913155],
#        [0.35242826],
#        [0.35506412],
#        [0.35728735],
#        [0.359364  ],
#        [0.3615542 ],
#        [0.36416045],
#        [0.36735582],
#        [0.37115923],
#        [0.3752443 ],
#        [0.37927878],
#        [0.38295507],
#        [0.38601357],
#        [0.38828158],
#        [0.3896559 ],
#        [0.39014292],
#        [0.38992006],
#        [0.38920897],
#        [0.38831222],
#        [0.3875181 ],
#        [0.3870802 ],
#        [0.3872818 ],
#        [0.38844886],
#        [0.39079928],
#        [0.3943987 ],
#        [0.39925572],
#        [0.4052869 ],
#        [0.41222495],
#        [0.41985282],
#        [0.42793977],
#        [0.4362586 ],
#        [0.44466707],
#        [0.45250902],
#        [0.45904884],
#        [0.46383998],
#        [0.46665767],
#        [0.4674872 ],
#        [0.46675998],
#        [0.4650812 ],
#        [0.46307245],
#        [0.46123135],
#        [0.45980284],
#        [0.45895228],
#        [0.45876816],
#        [0.4591621 ],
#        [0.4599872 ],
#        [0.4612568 ],
#        [0.46289667],
#        [0.46436778],
#        [0.4654443 ],
#        [0.465993  ],
#        [0.46604556],
#        [0.46553525],
#        [0.4644995 ],
#        [0.46300468],
#        [0.46114722],
#        [0.4589507 ],
#        [0.45665765],
#        [0.45455787],
#        [0.45285988],
#        [0.45158297],
#        [0.45055306],
#        [0.4494482 ],
#        [0.4478816 ],
#        [0.44571757],
#        [0.44316638],
#        [0.44082776],
#        [0.43934166],
#        [0.4393904 ],
#        [0.44147423],
#        [0.44576862],
#        [0.452281  ],
#        [0.46083137],
#        [0.47110444],
#        [0.4827389 ],
#        [0.49546066],
#        [0.5088414 ],
#        [0.5224124 ],
#        [0.53568494],
#        [0.5482501 ],
#        [0.55975527],
#        [0.57004213],
#        [0.57923436],
#        [0.5876951 ],
#        [0.5959214 ],
#        [0.6042417 ],
#        [0.61297274],
#        [0.62212896],
#        [0.6317501 ],
#        [0.64176977],
#        [0.652297  ],
#        [0.66317904],
#        [0.6743208 ],
#        [0.6855357 ],
#        [0.6959866 ],
#        [0.70480394],
#        [0.7115736 ],
#        [0.71612227],
#        [0.71842515],
#        [0.7183087 ],
#        [0.71598184],
#        [0.71157384],
#        [0.70529294],
#        [0.6972479 ],
#        [0.6874703 ],
#        [0.67611694],
#        [0.6636882 ],
#        [0.6510751 ],
#        [0.63909495],
#        [0.6284862 ],
#        [0.6198983 ],
#        [0.61357045],
#        [0.60970306],
#        [0.6083106 ],
#        [0.6090338 ],
#        [0.61109936],
#        [0.61360145],
#        [0.6154423 ],
#        [0.615837  ],
#        [0.61451304],
#        [0.6119878 ],
#        [0.6090505 ],
#        [0.60606825],
#        [0.6033259 ],
#        [0.6009696 ],
#        [0.5987314 ],
#        [0.5961728 ],
#        [0.5932795 ],
#        [0.5903157 ],
#        [0.58795214],
#        [0.58679664],
#        [0.58728695],
#        [0.5890992 ],
#        [0.59245366],
#        [0.5979886 ],
#        [0.6059246 ],
#        [0.6163088 ],
#        [0.62888503],
#        [0.6432646 ],
#        [0.65893435],
#        [0.6751087 ],
#        [0.69108826],
#        [0.706591  ],
#        [0.72181237],
#        [0.7371099 ],
#        [0.752733  ],
#        [0.76877236],
#        [0.7851918 ],
#        [0.80170846],
#        [0.81804824],
#        [0.83434904],
#        [0.85050046],
#        [0.865639  ],
#        [0.87915444],
#        [0.8902614 ],
#        [0.89857745],
#        [0.9040197 ],
#        [0.9065919 ],
#        [0.90615153],
#        [0.90279627],
#        [0.8969327 ],
#        [0.88880897],
#        [0.8786347 ],
#        [0.866943  ],
#        [0.85435164],
#        [0.84152627],
#        [0.82926905],
#        [0.81845737],
#        [0.8097254 ],
#        [0.80316234],
#        [0.79877615],
#        [0.79650664],
#        [0.795593  ],
#        [0.79536986],
#        [0.79518235],
#        [0.79503334],
#        [0.79480433],
#        [0.79439497],
#        [0.79391575],
#        [0.7938101 ],
#        [0.79426515],
#        [0.795267  ],
#        [0.7968503 ],
#        [0.79907405],
#        [0.80188787],
#        [0.8050821 ],
#        [0.80848324],
#        [0.8118316 ],
#        [0.81467927],
#        [0.8171021 ],
#        [0.8191681 ],
#        [0.82120156],
#        [0.8236277 ],
#        [0.8268188 ],
#        [0.8313236 ],
#        [0.83710194],
#        [0.84351337],
#        [0.84929323],
#        [0.8539959 ],
#        [0.8574332 ],
#        [0.85915995],
#        [0.8588078 ],
#        [0.8563074 ],
#        [0.8521869 ],
#        [0.8469807 ],
#        [0.8411108 ],
#        [0.83494985],
#        [0.8291973 ],
#        [0.8244239 ],
#        [0.82130444],
#        [0.8202034 ],
#        [0.8211782 ],
#        [0.8242537 ],
#        [0.8294388 ],
#        [0.8360423 ],
#        [0.84364545],
#        [0.8517895 ],
#        [0.85977435],
#        [0.8670552 ],
#        [0.8731383 ],
#        [0.877736  ],
#        [0.8806199 ],
#        [0.88162863],
#        [0.8806523 ],
#        [0.87771475],
#        [0.8733541 ],
#        [0.86806405],
#        [0.8621193 ],
#        [0.85572934],
#        [0.84918714],
#        [0.8427441 ],
#        [0.8367008 ],
#        [0.83114195],
#        [0.8262316 ],
#        [0.82202506],
#        [0.81867397],
#        [0.81620634],
#        [0.8145181 ],
#        [0.81313145],
#        [0.81173754],
#        [0.8103403 ],
#        [0.80901885],
#        [0.8078083 ],
#        [0.8066931 ],
#        [0.8052081 ],
#        [0.8026556 ],
#        [0.79905057],
#        [0.7949097 ],
#        [0.7908211 ],
#        [0.7874923 ],
#        [0.78572834],
#        [0.7861899 ],
#        [0.78955257],
#        [0.7958884 ],
#        [0.80394685],
#        [0.8122996 ],
#        [0.819679  ],
#        [0.8249922 ],
#        [0.8276925 ],
#        [0.8276274 ],
#        [0.8249068 ],
#        [0.8198091 ],
#        [0.8124894 ],
#        [0.80288064],
#        [0.79121935],
#        [0.7778672 ],
#        [0.7632468 ],
#        [0.7484062 ],
#        [0.7337111 ],
#        [0.71956754],
#        [0.7063229 ],
#        [0.6943475 ],
#        [0.6839833 ],
#        [0.67540145],
#        [0.66861343],
#        [0.66323644],
#        [0.6580475 ],
#        [0.6518136 ],
#        [0.64368284],
#        [0.6339508 ],
#        [0.62357926],
#        [0.6136707 ],
#        [0.6051102 ],
#        [0.5980383 ],
#        [0.5928638 ],
#        [0.5895258 ],
#        [0.5876707 ],
#        [0.58724535],
#        [0.58795357],
#        [0.58974755],
#        [0.59279025],
#        [0.59732604],
#        [0.6035682 ],
#        [0.61153495],
#        [0.6206764 ],
#        [0.6302172 ],
#        [0.63965446],
#        [0.648381  ],
#        [0.65604067],
#        [0.6625333 ],
#        [0.66784227],
#        [0.6717416 ],
#        [0.67364824],
#        [0.6733111 ],
#        [0.67068404],
#        [0.66605496],
#        [0.65989494],
#        [0.6528138 ],
#        [0.6453625 ],
#        [0.63784254],
#        [0.63080645],
#        [0.6246711 ],
#        [0.6196736 ],
#        [0.6157503 ],
#        [0.6129308 ],
#        [0.61111176],
#        [0.61022043],
#        [0.61041474],
#        [0.61181295],
#        [0.6146414 ],
#        [0.6194624 ],
#        [0.626122  ],
#        [0.634043  ],
#        [0.6431775 ],
#        [0.65365064],
#        [0.6652982 ],
#        [0.6779927 ],
#        [0.69166183],
#        [0.70599806],
#        [0.7203764 ],
#        [0.73413813],
#        [0.7466246 ],
#        [0.75675106],
#        [0.7637116 ],
#        [0.76705503],
#        [0.7663306 ],
#        [0.7617514 ],
#        [0.7538518 ],
#        [0.74382174],
#        [0.7330711 ],
#        [0.7228973 ],
#        [0.7140721 ],
#        [0.70714736],
#        [0.7022747 ],
#        [0.6993288 ],
#        [0.6981094 ],
#        [0.6982031 ],
#        [0.6990247 ],
#        [0.69992685],
#        [0.7009027 ],
#        [0.7020073 ],
#        [0.7032937 ],
#        [0.7044358 ],
#        [0.705178  ],
#        [0.7049825 ],
#        [0.70337284],
#        [0.6998863 ],
#        [0.6944499 ],
#        [0.68702775],
#        [0.67754227],
#        [0.6662494 ],
#        [0.6535566 ],
#        [0.6400975 ],
#        [0.62647843],
#        [0.6131251 ],
#        [0.6005448 ]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([0.06493205])

# %%
scale_factor = 1/0.06493205
y_predicted = y_predicted * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test, 'b',label = 'Original Price')
plt.plot(y_predicted, 'r',label = 'Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
